# %% [markdown]
# # testing some stuff

# %%
from configs import ExperimentConfig
from env2 import AuctionEnv

config = ExperimentConfig()
env = AuctionEnv(config)

state = env.reset()
print(state)
# Out:
# {'timestep': 0, 'history': []}
